# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/diamler_17_jan/blob/main/04_Azure_MLipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azureml.core
# !pip install azureml-dataset-runtime --upgrade
# !pip install pyarrow

# %%
# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
from azureml.core import Workspace, Dataset

subscription_id = 'c7257318-d8cc-4c8a-ad76-290e0fad39f7'
resource_group = 'popye'
workspace_name = 'proton'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='bca')
dataset.to_pandas_dataframe()
# Out:
#            id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302         M  ...          0.4601                  0.11890
# 1      842517         M  ...          0.2750                  0.08902
# 2    84300903         M  ...          0.3613                  0.08758
# 3    84348301         M  ...          0.6638                  0.17300
# 4    84358402         M  ...          0.2364                  0.07678
# ..        ...       ...  ...             ...                      ...
# 564    926424         M  ...          0.2060                  0.07115
# 565    926682         M  ...          0.2572                  0.06637
# 566    926954         M  ...          0.2218                  0.07820
# 567    927241         M  ...          0.4087                  0.12400
# 568     92751         B  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
import pandas as pd
data = dataset.to_pandas_dataframe()
data.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
data.info()
# check for null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data2 = data.iloc[:, :12]
data2.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'],
#       dtype='object')

# %%
data2.set_index('id', inplace=True)

# %%
data2.head()
# Out:
#          diagnosis  radius_mean  ...  symmetry_mean  fractal_dimension_mean
# id                               ...
# 842302           M        17.99  ...         0.2419                 0.07871
# 842517           M        20.57  ...         0.1812                 0.05667
# 84300903         M        19.69  ...         0.2069                 0.05999
# 84348301         M        11.42  ...         0.2597                 0.09744
# 84358402         M        20.29  ...         0.1809                 0.05883
#
# [5 rows x 11 columns]

# %%
dataforzscore = data2.iloc[:, 2:]
dataforzscore.head()
# Out:
#           texture_mean  perimeter_mean  ...  symmetry_mean  fractal_dimension_mean
# id                                      ...
# 842302           10.38          122.80  ...         0.2419                 0.07871
# 842517           17.77          132.90  ...         0.1812                 0.05667
# 84300903         21.25          130.00  ...         0.2069                 0.05999
# 84348301         20.38           77.58  ...         0.2597                 0.09744
# 84358402         14.34          135.10  ...         0.1809                 0.05883
#
# [5 rows x 9 columns]

# %%
stats = dataforzscore.describe().T
stats
# Out:
#                         count        mean  ...        75%         max
# texture_mean            569.0   19.289649  ...   21.80000    39.28000
# perimeter_mean          569.0   91.969033  ...  104.10000   188.50000
# area_mean               569.0  654.889104  ...  782.70000  2501.00000
# smoothness_mean         569.0    0.096360  ...    0.10530     0.16340
# compactness_mean        569.0    0.104341  ...    0.13040     0.34540
# concavity_mean          569.0    0.088799  ...    0.13070     0.42680
# concave points_mean     569.0    0.048919  ...    0.07400     0.20120
# symmetry_mean           569.0    0.181162  ...    0.19570     0.30400
# fractal_dimension_mean  569.0    0.062798  ...    0.06612     0.09744
#
# [9 rows x 8 columns]

# %%
zscoreddata = (dataforzscore - stats['mean'])/stats['std']
# zscore-> data-mean/std

# %%
zscoreddata.head()
# Out:
#           texture_mean  perimeter_mean  ...  symmetry_mean  fractal_dimension_mean
# id                                      ...
# 842302       -2.071512        1.268817  ...       2.215566                2.253764
# 842517       -0.353322        1.684473  ...       0.001391               -0.867889
# 84300903      0.455786        1.565126  ...       0.938859               -0.397658
# 84348301      0.253509       -0.592166  ...       2.864862                4.906602
# 84358402     -1.150804        1.775011  ...      -0.009552               -0.561956
#
# [5 rows x 9 columns]

# %%
zscoreddata['diagnosis'] = data2['diagnosis']
# after z-scoring, DON't forget to add the label column back!

# %%
zscoreddata.head()
# Out:
#           texture_mean  perimeter_mean  ...  fractal_dimension_mean  diagnosis
# id                                      ...
# 842302       -2.071512        1.268817  ...                2.253764          M
# 842517       -0.353322        1.684473  ...               -0.867889          M
# 84300903      0.455786        1.565126  ...               -0.397658          M
# 84348301      0.253509       -0.592166  ...                4.906602          M
# 84358402     -1.150804        1.775011  ...               -0.561956          M
#
# [5 rows x 10 columns]

# %%
# Once done with all the changes-> upload this new table back into azure
# 2 ways:
# either 1) Create a new dataset
# or 2) Update the dataset with a new VERSION

# %%
from azureml.core import Datastore

# %%
datastore = Datastore.get_default(workspace)
dataset = Dataset.Tabular.register_pandas_dataframe(zscoreddata, datastore, "cleandata", show_progress=True)
# Out:
# Validating arguments.
# Arguments validated.
# Successfully obtained datastore reference and path.
# Uploading file to managed-dataset/2a25bcb9-3e8f-4223-9f41-c92432604351/
# Successfully uploaded file to datastore.
# Creating and registering a new dataset.
# Successfully created and registered a new dataset.

# %%
dir(Datastore)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_client',
#  'get',
#  'get_default',
#  'register_azure_blob_container',
#  'register_azure_data_lake',
#  'register_azure_data_lake_gen2',
#  'register_azure_file_share',
#  'register_azure_my_sql',
#  'register_azure_postgre_sql',
#  'register_azure_sql_database',
#  'register_dbfs',
#  'set_as_default',
#  'unregister']
